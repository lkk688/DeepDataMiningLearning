# %%
# !python -V
# Out:
# Python 3.10.11

# %%
import torch
print(torch.__version__)
# Out:
# 2.0.1

# %%
# import datasets
from torchtext.datasets import IMDB

train_iter = IMDB(split='train')

# %%
train_iter
# Out:
# ShardingFilterIterDataPipe

# %%
def tokenize(label, line):
    return line.split()

tokens = []
for label, line in train_iter:
    print(label)
    #tokens += tokenize(label, line)
# Out:
# /home/010796032/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/iter/combining.py:297: UserWarning: Some child DataPipes are not exhausted when __iter__ is called. We are resetting the buffer and each child DataPipe will read from the start again.
#   warnings.warn("Some child DataPipes are not exhausted when __iter__ is called. We are resetting "
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 5
#       2     return line.split()
#       4 tokens = []
# ----> 5 for label, line in train_iter:
#       6     print(label)
#       7     #tokens += tokenize(label, line)
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/_hook_iterator.py:173, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     171         response = gen.send(None)
#     172 else:
# --> 173     response = gen.send(None)
#     175 while True:
#     176     datapipe._number_of_samples_yielded += 1
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/iter/sharding.py:75, in ShardingFilterIterDataPipe.__iter__(self)
#      74 def __iter__(self):
# ---> 75     for i, item in enumerate(self.source_datapipe):
#      76         if i % self.num_of_instances == self.instance_id:
#      77             yield item
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/_hook_iterator.py:173, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     171         response = gen.send(None)
#     172 else:
# --> 173     response = gen.send(None)
#     175 while True:
#     176     datapipe._number_of_samples_yielded += 1
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/iter/combinatorics.py:124, in ShufflerIterDataPipe.__iter__(self)
#     122 def __iter__(self) -> Iterator[T_co]:
#     123     if not self._enabled:
# --> 124         for x in self.datapipe:
#     125             yield x
#     126     else:
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/_hook_iterator.py:173, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     171         response = gen.send(None)
#     172 else:
# --> 173     response = gen.send(None)
#     175 while True:
#     176     datapipe._number_of_samples_yielded += 1
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/iter/callable.py:122, in MapperIterDataPipe.__iter__(self)
#     121 def __iter__(self) -> Iterator[T_co]:
# --> 122     for data in self.datapipe:
#     123         yield self._apply_fn(data)
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/_hook_iterator.py:173, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     171         response = gen.send(None)
#     172 else:
# --> 173     response = gen.send(None)
#     175 while True:
#     176     datapipe._number_of_samples_yielded += 1
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torchdata/datapipes/iter/util/plain_text_reader.py:134, in LineReaderIterDataPipe.__iter__(self)
#     133 def __iter__(self) -> Iterator[Union[Str_Or_Bytes, Tuple[str, Str_Or_Bytes]]]:
# --> 134     for path, file in self.source_datapipe:
#     135         stream = self._helper.skip_lines(file)
#     136         stream = self._helper.strip_newline(stream)
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/_hook_iterator.py:173, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     171         response = gen.send(None)
#     172 else:
# --> 173     response = gen.send(None)
#     175 while True:
#     176     datapipe._number_of_samples_yielded += 1
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/iter/fileopener.py:67, in FileOpenerIterDataPipe.__iter__(self)
#      66 def __iter__(self):
# ---> 67     yield from get_file_binaries_from_pathnames(self.datapipe, self.mode, self.encoding)
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/utils/common.py:210, in get_file_binaries_from_pathnames(pathnames, mode, encoding)
#     207 if mode in ('b', 't'):
#     208     mode = 'r' + mode
# --> 210 for pathname in pathnames:
#     211     if not isinstance(pathname, str):
#     212         raise TypeError("Expected string type for pathname, but got {}"
#     213                         .format(type(pathname)))
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/_hook_iterator.py:173, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     171         response = gen.send(None)
#     172 else:
# --> 173     response = gen.send(None)
#     175 while True:
#     176     datapipe._number_of_samples_yielded += 1
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/iter/combining.py:52, in ConcaterIterDataPipe.__iter__(self)
#      50 def __iter__(self) -> Iterator:
#      51     for dp in self.datapipes:
# ---> 52         for data in dp:
#      53             yield data
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/_hook_iterator.py:173, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     171         response = gen.send(None)
#     172 else:
# --> 173     response = gen.send(None)
#     175 while True:
#     176     datapipe._number_of_samples_yielded += 1
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/iter/combining.py:52, in ConcaterIterDataPipe.__iter__(self)
#      50 def __iter__(self) -> Iterator:
#      51     for dp in self.datapipes:
# ---> 52         for data in dp:
#      53             yield data
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/_hook_iterator.py:173, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     171         response = gen.send(None)
#     172 else:
# --> 173     response = gen.send(None)
#     175 while True:
#     176     datapipe._number_of_samples_yielded += 1
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torchdata/datapipes/iter/util/cacheholder.py:454, in _FulfilledPromisesIterDataPipe.__iter__(self)
#     449         # TODO(VitalyFedyunin): If no match found, that means we exceeded length of memory_cell
#     450         # and there is aggressive amount 1-to-zero cases, raise error and explain how to fix
#     452 try:
# --> 454     for filename in self.source_datapipe:
#     455         rec_uuid, record = self.memory_cell_dp.get_last()
#     456         original_file_name = self.first_filepath_fn(record)
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/_hook_iterator.py:173, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     171         response = gen.send(None)
#     172 else:
# --> 173     response = gen.send(None)
#     175 while True:
#     176     datapipe._number_of_samples_yielded += 1
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torchdata/datapipes/iter/util/saver.py:53, in SaverIterDataPipe.__iter__(self)
#      52 def __iter__(self) -> Iterator[str]:
# ---> 53     for filepath, data in self.source_datapipe:
#      54         if self.fn is not None:
#      55             filepath = self.fn(filepath)
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/_hook_iterator.py:173, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     171         response = gen.send(None)
#     172 else:
# --> 173     response = gen.send(None)
#     175 while True:
#     176     datapipe._number_of_samples_yielded += 1
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/iter/callable.py:122, in MapperIterDataPipe.__iter__(self)
#     121 def __iter__(self) -> Iterator[T_co]:
# --> 122     for data in self.datapipe:
#     123         yield self._apply_fn(data)
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/_hook_iterator.py:173, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     171         response = gen.send(None)
#     172 else:
# --> 173     response = gen.send(None)
#     175 while True:
#     176     datapipe._number_of_samples_yielded += 1
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/iter/callable.py:122, in MapperIterDataPipe.__iter__(self)
#     121 def __iter__(self) -> Iterator[T_co]:
# --> 122     for data in self.datapipe:
#     123         yield self._apply_fn(data)
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/_hook_iterator.py:173, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     171         response = gen.send(None)
#     172 else:
# --> 173     response = gen.send(None)
#     175 while True:
#     176     datapipe._number_of_samples_yielded += 1
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torchdata/datapipes/iter/util/paragraphaggregator.py:53, in ParagraphAggregatorIterDataPipe.__iter__(self)
#      51 def __iter__(self) -> Iterator[Tuple[str, str]]:
#      52     prev_filename = None
# ---> 53     for filename, line in self.source_datapipe:
#      54         if prev_filename is None:
#      55             prev_filename = filename
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/_hook_iterator.py:173, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     171         response = gen.send(None)
#     172 else:
# --> 173     response = gen.send(None)
#     175 while True:
#     176     datapipe._number_of_samples_yielded += 1
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torchdata/datapipes/iter/util/plain_text_reader.py:134, in LineReaderIterDataPipe.__iter__(self)
#     133 def __iter__(self) -> Iterator[Union[Str_Or_Bytes, Tuple[str, Str_Or_Bytes]]]:
# --> 134     for path, file in self.source_datapipe:
#     135         stream = self._helper.skip_lines(file)
#     136         stream = self._helper.strip_newline(stream)
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/_hook_iterator.py:173, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     171         response = gen.send(None)
#     172 else:
# --> 173     response = gen.send(None)
#     175 while True:
#     176     datapipe._number_of_samples_yielded += 1
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/iter/callable.py:122, in MapperIterDataPipe.__iter__(self)
#     121 def __iter__(self) -> Iterator[T_co]:
# --> 122     for data in self.datapipe:
#     123         yield self._apply_fn(data)
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/_hook_iterator.py:173, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     171         response = gen.send(None)
#     172 else:
# --> 173     response = gen.send(None)
#     175 while True:
#     176     datapipe._number_of_samples_yielded += 1
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/iter/selecting.py:71, in FilterIterDataPipe.__iter__(self)
#      70 def __iter__(self) -> Iterator[T_co]:
# ---> 71     for data in self.datapipe:
#      72         condition, filtered = self._returnIfTrue(data)
#      73         if condition:
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/_hook_iterator.py:173, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     171         response = gen.send(None)
#     172 else:
# --> 173     response = gen.send(None)
#     175 while True:
#     176     datapipe._number_of_samples_yielded += 1
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torchdata/datapipes/iter/util/tararchiveloader.py:54, in TarArchiveLoaderIterDataPipe.__iter__(self)
#      53 def __iter__(self) -> Iterator[Tuple[str, BufferedIOBase]]:
# ---> 54     for data in self.datapipe:
#      55         validate_pathname_binary_tuple(data)
#      56         pathname, data_stream = data
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/_hook_iterator.py:173, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     171         response = gen.send(None)
#     172 else:
# --> 173     response = gen.send(None)
#     175 while True:
#     176     datapipe._number_of_samples_yielded += 1
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/iter/fileopener.py:67, in FileOpenerIterDataPipe.__iter__(self)
#      66 def __iter__(self):
# ---> 67     yield from get_file_binaries_from_pathnames(self.datapipe, self.mode, self.encoding)
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/utils/common.py:210, in get_file_binaries_from_pathnames(pathnames, mode, encoding)
#     207 if mode in ('b', 't'):
#     208     mode = 'r' + mode
# --> 210 for pathname in pathnames:
#     211     if not isinstance(pathname, str):
#     212         raise TypeError("Expected string type for pathname, but got {}"
#     213                         .format(type(pathname)))
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/_hook_iterator.py:173, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     171         response = gen.send(None)
#     172 else:
# --> 173     response = gen.send(None)
#     175 while True:
#     176     datapipe._number_of_samples_yielded += 1
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torchdata/datapipes/iter/util/cacheholder.py:229, in OnDiskCacheHolderIterDataPipe.__iter__(self)
#     227 def __iter__(self):
#     228     if self._end_caching_flag:
# --> 229         yield from self.source_datapipe
#     230     else:
#     231         # In case of BC breaking, use RuntimeError for now. Warning is another option
#     232         raise RuntimeError("Please call `end_caching()` before iteration.")
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/_hook_iterator.py:173, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     171         response = gen.send(None)
#     172 else:
# --> 173     response = gen.send(None)
#     175 while True:
#     176     datapipe._number_of_samples_yielded += 1
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torchdata/datapipes/iter/util/cacheholder.py:374, in _MemoryCellIterDataPipe.__iter__(self)
#     373 def __iter__(self):
# --> 374     for item in self.source_datapipe:
#     375         item_id = uuid.uuid4()
#     376         self.buffer_pos = (self.buffer_pos + 1) % self.remember_elements
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/_hook_iterator.py:144, in hook_iterator.<locals>.IteratorDecorator.__next__(self)
#     142         return self._get_next()
#     143 else:  # Decided against using `contextlib.nullcontext` for performance reasons
# --> 144     return self._get_next()
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/_hook_iterator.py:132, in hook_iterator.<locals>.IteratorDecorator._get_next(self)
#     128 r"""
#     129 Return next with logic related to iterator validity, profiler, and incrementation of samples yielded.
#     130 """
#     131 _check_iterator_valid(self.source_dp, self.iterator_id)
# --> 132 result = next(self.iterator)
#     133 if not self.self_and_has_next_method:
#     134     self.source_dp._number_of_samples_yielded += 1
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/iter/combining.py:427, in _DemultiplexerIterDataPipe.get_next_element_by_instance(self, instance_id)
#     425 else:
#     426     try:
# --> 427         yield self._find_next(instance_id)
#     428     except StopIteration:
#     429         self._child_stop[instance_id] = True
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/iter/combining.py:396, in _DemultiplexerIterDataPipe._find_next(self, instance_id)
#     392 if self._datapipe_iterator is None:
#     393     raise ValueError(
#     394         "_datapipe_iterator has not been set, likely because this private method is called directly "
#     395         "without invoking get_next_element_by_instance() first.")
# --> 396 value = next(self._datapipe_iterator)
#     397 classification = self.classifier_fn(value)
#     398 if classification is None and self.drop_none:
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/_hook_iterator.py:173, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     171         response = gen.send(None)
#     172 else:
# --> 173     response = gen.send(None)
#     175 while True:
#     176     datapipe._number_of_samples_yielded += 1
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/iter/combining.py:52, in ConcaterIterDataPipe.__iter__(self)
#      50 def __iter__(self) -> Iterator:
#      51     for dp in self.datapipes:
# ---> 52         for data in dp:
#      53             yield data
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/_hook_iterator.py:173, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     171         response = gen.send(None)
#     172 else:
# --> 173     response = gen.send(None)
#     175 while True:
#     176     datapipe._number_of_samples_yielded += 1
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/iter/combining.py:52, in ConcaterIterDataPipe.__iter__(self)
#      50 def __iter__(self) -> Iterator:
#      51     for dp in self.datapipes:
# ---> 52         for data in dp:
#      53             yield data
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/_hook_iterator.py:173, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     171         response = gen.send(None)
#     172 else:
# --> 173     response = gen.send(None)
#     175 while True:
#     176     datapipe._number_of_samples_yielded += 1
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torchdata/datapipes/iter/util/cacheholder.py:454, in _FulfilledPromisesIterDataPipe.__iter__(self)
#     449         # TODO(VitalyFedyunin): If no match found, that means we exceeded length of memory_cell
#     450         # and there is aggressive amount 1-to-zero cases, raise error and explain how to fix
#     452 try:
# --> 454     for filename in self.source_datapipe:
#     455         rec_uuid, record = self.memory_cell_dp.get_last()
#     456         original_file_name = self.first_filepath_fn(record)
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/_hook_iterator.py:173, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     171         response = gen.send(None)
#     172 else:
# --> 173     response = gen.send(None)
#     175 while True:
#     176     datapipe._number_of_samples_yielded += 1
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torchdata/datapipes/iter/util/saver.py:53, in SaverIterDataPipe.__iter__(self)
#      52 def __iter__(self) -> Iterator[str]:
# ---> 53     for filepath, data in self.source_datapipe:
#      54         if self.fn is not None:
#      55             filepath = self.fn(filepath)
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/_hook_iterator.py:173, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     171         response = gen.send(None)
#     172 else:
# --> 173     response = gen.send(None)
#     175 while True:
#     176     datapipe._number_of_samples_yielded += 1
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torchdata/datapipes/iter/util/hashchecker.py:67, in HashCheckerIterDataPipe.__iter__(self)
#      66 def __iter__(self) -> Iterator[Tuple[str, StreamWrapper]]:
# ---> 67     for file_name, data in self.source_datapipe:
#      68         if self.hash_type == "sha256":
#      69             hash_func = hashlib.sha256()
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/_hook_iterator.py:173, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     171         response = gen.send(None)
#     172 else:
# --> 173     response = gen.send(None)
#     175 while True:
#     176     datapipe._number_of_samples_yielded += 1
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/iter/callable.py:122, in MapperIterDataPipe.__iter__(self)
#     121 def __iter__(self) -> Iterator[T_co]:
# --> 122     for data in self.datapipe:
#     123         yield self._apply_fn(data)
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/_hook_iterator.py:173, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     171         response = gen.send(None)
#     172 else:
# --> 173     response = gen.send(None)
#     175 while True:
#     176     datapipe._number_of_samples_yielded += 1
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/iter/callable.py:122, in MapperIterDataPipe.__iter__(self)
#     121 def __iter__(self) -> Iterator[T_co]:
# --> 122     for data in self.datapipe:
#     123         yield self._apply_fn(data)
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/_hook_iterator.py:173, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     171         response = gen.send(None)
#     172 else:
# --> 173     response = gen.send(None)
#     175 while True:
#     176     datapipe._number_of_samples_yielded += 1
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torchdata/datapipes/iter/load/online.py:84, in HTTPReaderIterDataPipe.__iter__(self)
#      83 def __iter__(self) -> Iterator[Tuple[str, StreamWrapper]]:
# ---> 84     for url in self.source_datapipe:
#      85         try:
#      86             yield _get_response_from_http(url, timeout=self.timeout, **self.query_params)
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/_hook_iterator.py:173, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     171         response = gen.send(None)
#     172 else:
# --> 173     response = gen.send(None)
#     175 while True:
#     176     datapipe._number_of_samples_yielded += 1
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torchdata/datapipes/iter/util/cacheholder.py:229, in OnDiskCacheHolderIterDataPipe.__iter__(self)
#     227 def __iter__(self):
#     228     if self._end_caching_flag:
# --> 229         yield from self.source_datapipe
#     230     else:
#     231         # In case of BC breaking, use RuntimeError for now. Warning is another option
#     232         raise RuntimeError("Please call `end_caching()` before iteration.")
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/_hook_iterator.py:173, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     171         response = gen.send(None)
#     172 else:
# --> 173     response = gen.send(None)
#     175 while True:
#     176     datapipe._number_of_samples_yielded += 1
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torchdata/datapipes/iter/util/cacheholder.py:374, in _MemoryCellIterDataPipe.__iter__(self)
#     373 def __iter__(self):
# --> 374     for item in self.source_datapipe:
#     375         item_id = uuid.uuid4()
#     376         self.buffer_pos = (self.buffer_pos + 1) % self.remember_elements
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/_hook_iterator.py:144, in hook_iterator.<locals>.IteratorDecorator.__next__(self)
#     142         return self._get_next()
#     143 else:  # Decided against using `contextlib.nullcontext` for performance reasons
# --> 144     return self._get_next()
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/_hook_iterator.py:132, in hook_iterator.<locals>.IteratorDecorator._get_next(self)
#     128 r"""
#     129 Return next with logic related to iterator validity, profiler, and incrementation of samples yielded.
#     130 """
#     131 _check_iterator_valid(self.source_dp, self.iterator_id)
# --> 132 result = next(self.iterator)
#     133 if not self.self_and_has_next_method:
#     134     self.source_dp._number_of_samples_yielded += 1
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/iter/combining.py:427, in _DemultiplexerIterDataPipe.get_next_element_by_instance(self, instance_id)
#     425 else:
#     426     try:
# --> 427         yield self._find_next(instance_id)
#     428     except StopIteration:
#     429         self._child_stop[instance_id] = True
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torch/utils/data/datapipes/iter/combining.py:397, in _DemultiplexerIterDataPipe._find_next(self, instance_id)
#     393     raise ValueError(
#     394         "_datapipe_iterator has not been set, likely because this private method is called directly "
#     395         "without invoking get_next_element_by_instance() first.")
#     396 value = next(self._datapipe_iterator)
# --> 397 classification = self.classifier_fn(value)
#     398 if classification is None and self.drop_none:
#     399     StreamWrapper.close_streams(value)
#
# File ~/miniconda3/envs/mycondapy310/lib/python3.10/site-packages/torchdata/datapipes/iter/util/cacheholder.py:262, in OnDiskCacheHolderIterDataPipe._cache_check_fn(data, filepath_fn, hash_dict, hash_type, extra_check_fn, cache_uuid)
#     259 if not os.path.exists(dirname):
#     260     os.makedirs(dirname)
# --> 262 with portalocker.Lock(promise_filepath, "a+", flags=portalocker.LockFlags.EXCLUSIVE) as promise_fh:
#     263     promise_fh.seek(0)
#     264     data = promise_fh.read()
#
# AttributeError: 'NoneType' object has no attribute 'Lock'
# This exception is thrown by __iter__ of _MemoryCellIterDataPipe(remember_elements=1000, source_datapipe=_ChildDataPipe)

# %%
tokens
# Out:
# []

# %%
dataroot = "/data/cmpe249-fa23/torchhome/"
from torchtext.datasets import WikiText2
wikirain_iter = WikiText2(root=dataroot, split='train')

# %%
next(iter(wikirain_iter))
# Out:
# ' \n'

# %%
from torchtext.datasets import AG_NEWS

train_iter = iter(AG_NEWS(split="train"))

# %%
next(train_iter)
# Out:
# (3,
#  'Iraq Halts Oil Exports from Main Southern Pipeline (Reuters) Reuters - Authorities have halted oil export\\flows from the main pipeline in southern Iraq after\\intelligence showed a rebel militia could strike\\infrastructure, an oil official said on Saturday.')
